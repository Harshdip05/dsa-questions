# %%
n = 3
lst = [0, 0, 1]

hard = 0
for i in range(len(lst)):
    # print(lst[i])
    if lst[i]==1:
        hard +=1
        if hard>=1:
            print("HARD")
            break
else:
    print("EASY")
# Out:
# HARD

# %%
n = int(input())
opinions = list(map(int, input().split()))
print(opinions)

hard = 0
for i in range(len(lst)):
    # print(lst[i])
    if lst[i]==1:
        hard +=1
        if hard>=1:
            print("HARD")
            break
else:
    print("EASY")
# Out:
# [1, 1]
# HARD

# %%
n = int(input())
opinions = list(map(int, input().split()))

for x in opinions:
    if x == 1:
        print("HARD")
        break
else:
    print("EASY")

# %%
n = int(input())
opinions = list(map(int, input().split()))

if 1 in opinions:
    print("HARD")
else:
    print("EASY")
