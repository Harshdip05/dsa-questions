# %%
X = 0
n = 2

for i in range(n):
    s = input()
    if s == "++X" or  s == "X++":
        X += 1
    elif s == "--X" or s == "X--":
        X -= 1    
    print(X)    
print(X)

# %%
X = 0
n = 2

for i in range(n):
    s = input()
    if "++" in s:
        X += 1
    elif "--" in s:
        X -= 1    
    # print(X)    
print(X)

# %%
X = 0
n = int(input())

for _ in range(n):
    s = input()
    if "+" in s:
        X += 1
    else:
        X -= 1

print(X)
