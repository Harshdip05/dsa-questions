# %% [markdown]
# Input
# The only line of input contains the name of some exhibit — the non-empty string consisting of no more than 100 characters. It's guaranteed that the string consists of only lowercase English letters.
#
# Output
# Print one integer — the minimum number of rotations of the wheel, required to print the name given in the input.

# %%
alpha = "abcdefghijklmnopqrstuvwxyz"

s = "zeus"

current = 0

total = 0

for i in range(len(s)):
    target = alpha.index(s[i])
    distance = abs(current - target)
    moves = min(distance,26-distance)
    total += moves
    current = target

print(total)
# Out:
# 18

# %% [markdown]
# | Variation       | Topic                      |
# | --------------- | -------------------------- |
# | Original        | Greedy + Circular distance |
# | Blocked letters | Graph / BFS                |
# | Cost per press  | Greedy + Cost              |
# | Any start       | Optimization               |
# | Skip letters    | DP + Graph                 |
