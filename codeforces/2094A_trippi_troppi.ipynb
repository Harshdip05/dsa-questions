# %%
s = "united states america"
print(len(s))

x = s.split()
print(x)
y = ""
for i in range(len(x)):
    # print(i)
    y += x[i][0]

print(y)
# Out:
# 21
# ['united', 'states', 'america']
# usa

# %%
t = int(input())

s = input().split()
y = ""

for i in range(len(s)):
    y += s[i][0]

print(y)
# Out:
# us
