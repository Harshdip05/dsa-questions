# %%
n,a,b,c = 12,1,5,3

sum_ = 0
# i = 0
while sum_<=n:
    i = 1
    if a>=n :
        print(i) 
        sum_ = a
        break
    i += 1

    elif (sum_+b)>=n:
        print(i)
        sum_ += b
        break
    i += 1
    elif sum_+c >= n:
        print(i)
        sum_ += c
        break
    i += 1
# Out:
#   Cell In[6], line 5
#
#     ^
# SyntaxError: incomplete input
