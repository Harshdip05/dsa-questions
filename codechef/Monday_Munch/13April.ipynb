# %%
n = [1,2,3]

k = 3



for i in range(len(n)):
    for j in range(i,len(n)):
        # print(n[i:j+1])
# Out:
# [1]
# [1, 2]
# [1, 2, 3]
# [2]
# [2, 3]
# [3]

# %%
arr = [1,2,3]

subarrays = []
k = 3

for i in range(len(arr)):
    for j in range(i, len(arr)):
        subarrays.append(arr[i:j+1])

print(subarrays)
# print(sum(subarrays[1]))

count = 0
for z in range(len(subarrays)):
    if sum(subarrays[z])==k:
        count +=1

print(count)
# Out:
# [[1], [1, 2], [1, 2, 3], [2], [2, 3], [3]]
# 2

# %%
arr.sort(reverse=True)
