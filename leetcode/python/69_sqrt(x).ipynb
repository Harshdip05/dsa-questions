# %%
# round(2.8)
floor(2.8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # round(2.8)
# ----> 2 floor(2.8)
#
# NameError: name 'floor' is not defined
