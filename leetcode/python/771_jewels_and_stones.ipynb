# %%
from collections import Counter

jewels = "aA"
stones = "aAAbbbb"

j1 = Counter(jewels)
s1 = Counter(stones)

print(j1)
print(s1)
# Out:
# Counter({'a': 1, 'A': 1})
# Counter({'b': 4, 'A': 2, 'a': 1})

# %%
jewels = "aA"
stones = "aAAbbbb"

for i in range(len(stones)):
    # print(stones[i])

    if jewels in stones[i]:
        print("x")

    # if stones[i] in jewels[i]:
    #     print("x")

# %%
jewels = "aA"
stones = "aAAbbbb"

j1 = list(jewels)
s1 = list(stones)

print(j1)
print(s1)


for i in range(len(j1)):
    print(j1[i])

for j in range(len(stones)):
    print(s1[j])
# Out:
# ['a', 'A']
# ['a', 'A', 'A', 'b', 'b', 'b', 'b']
# a
# A
# a
# A
# A
# b
# b
# b
# b

# %%
jewels = "aA"
stones = "aAAbbbb"

for i in range(len(jewels)):
    print(jewels.count(jewels[i]))


for j in range(len(stones)):
    print(stones.count(stones[j]))
# Out:
# 1
# 1
# 1
# 2
# 2
# 4
# 4
# 4
# 4
