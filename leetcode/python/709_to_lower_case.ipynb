# %% [markdown]
# Given a string s, return the string after replacing every uppercase letter with the same lowercase letter.
#
#
#
# Example 1:
#
# Input: s = "Hello"
# Output: "hello"
# Example 2:
#
# Input: s = "here"
# Output: "here"
# Example 3:
#
# Input: s = "LOVELY"
# Output: "lovely"
#
#
# Constraints:
#
# 1 <= s.length <= 100
# s consists of printable ASCII characters.

# %%
print(ord("A"))
print(ord("a"))

print(ord("a")-ord("A"))
# Out:
# 65
# 97
# 32

# %%
"A"<"B"<"Z"
# Out:
# True

# %%
s = "HellO"
result = ""

for i in range(len(s)):
    if s[i].isupper():
        result += chr(ord(s[i]) + 32)
    else:
        result += s[i]

print(result)
# Out:
# hello

# %%
s = "HellO"
result = ""

for i in range(len(s)):
    if  "A" < s[i] < "Z":
        result  += chr(ord(s[i])+32)
    else:
        result += s[i]

print(result)
# Out:
# hello

# %%
s = "hello"

result = ""

for i in range(len(s)):
    if "A" <= s[i] <= "Z":
        result += chr(ord(s[i])|32)
    else:
        result += s[i]
print(result)
# Out:
# hello

# %%
class Solution:
    def toLowerCase(self, s: str) -> str:
        return s.lower()
    
# a = toLowerCase("Hello")
# print(a)    

# you're trying to call toLowerCase as a standalone function, while it's defined inside a class.
# In Python, methods inside a class must be called using an instance of that class (or made static).

# %%
# Create an object of the class

class Solution:
    def toLowerCase(self, s: str) -> str:
        return s.lower()

obj = Solution()
a = obj.toLowerCase("Hello")
print(a)
# Out:
# hello

# %%
# Make it a static method

class Solution:
    @staticmethod
    def toLowerCase(s: str) -> str:
        return s.lower()

a = Solution.toLowerCase("Hello")
print(a)
# Out:
# hello

# %%
s = "Hello"

if s.islower():
    print(s)
else:
    print(s.lower())
# Out:
# hello

# %%
s = "Hello"

if s.islower():
    print(s)

# %%
s = "HellO"
# print(s)

lst = []

for i in range(len(s)):
    if s[i].isupper():
        # print(s[i])
        lst.append(s[i])

print(lst)


s1 = "".join(lst)
print(s1.lower())
# Out:
# ['H', 'O']
# ho

# %%
s = "HellO"

z = [x for x in s if x.isupper()]
print(z)
# Out:
# ['H', 'O']
