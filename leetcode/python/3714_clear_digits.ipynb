# %%
s = "cb34"
# print(s)

digits = "0123456789"

sum = ""


for cx in s:
    # print(cx)
    for di in digits:
        if di != cx:
            # print(cx)
            sum += cx
    print(sum)
# Out:
# cccccccccc
# ccccccccccbbbbbbbbbb
# ccccccccccbbbbbbbbbb333333333
# ccccccccccbbbbbbbbbb333333333444444444
