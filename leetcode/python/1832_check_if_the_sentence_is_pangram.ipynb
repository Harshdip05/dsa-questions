# %%
from collections import Counter


sentence = "thequickbrownfoxjumpsoverthelazydog"

alpha = "abcdefghijklmnopqrstuvwxyz"
# print(len(alpha))

s1 = Counter(sentence)
print(s1)
a1 = Counter(alpha)
print(a1)

# print(s1-a1)
print(a1-s1)
# Out:
# Counter({'o': 4, 'e': 3, 't': 2, 'h': 2, 'u': 2, 'r': 2, 'q': 1, 'i': 1, 'c': 1, 'k': 1, 'b': 1, 'w': 1, 'n': 1, 'f': 1, 'x': 1, 'j': 1, 'm': 1, 'p': 1, 's': 1, 'v': 1, 'l': 1, 'a': 1, 'z': 1, 'y': 1, 'd': 1, 'g': 1})
# Counter({'a': 1, 'b': 1, 'c': 1, 'd': 1, 'e': 1, 'f': 1, 'g': 1, 'h': 1, 'i': 1, 'j': 1, 'k': 1, 'l': 1, 'm': 1, 'n': 1, 'o': 1, 'p': 1, 'q': 1, 'r': 1, 's': 1, 't': 1, 'u': 1, 'v': 1, 'w': 1, 'x': 1, 'y': 1, 'z': 1})
# Counter({'o': 3, 'e': 2, 't': 1, 'h': 1, 'u': 1, 'r': 1})
# Counter()

# %%
x = set(sentence)
print(x)
print(len(x))
if len(x) == 26:
            print(True)
else:
            print(False)
# Out:
# {'j', 'f', 'w', 'd', 'e', 'x', 'o', 'c', 'a', 'r', 'p', 'g', 'v', 'i', 'b', 'l', 's', 'z', 't', 'k', 'h', 'q', 'y', 'n', 'u', 'm'}
# 26
# True
