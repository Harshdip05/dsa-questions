# %% [markdown]
# An Anagram is a word or phrase formed by rearranging the letters of a different word or phrase, typically using all the original letters exactly once.
#
# Input:
#
# strs = ["",""]
#
# Expected:
#
# [["",""]]
#
# Anagrams have the same sorted character sequence

# %% [markdown]
# Given an array of strings strs, group the anagrams together. You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: strs = ["eat","tea","tan","ate","nat","bat"]
#
# Output: [["bat"],["nat","tan"],["ate","eat","tea"]]
#
# Explanation:
#
# There is no string in strs that can be rearranged to form "bat".
# The strings "nat" and "tan" are anagrams as they can be rearranged to form each other.
# The strings "ate", "eat", and "tea" are anagrams as they can be rearranged to form each other.
# Example 2:
#
# Input: strs = [""]
#
# Output: [[""]]
#
# Example 3:
#
# Input: strs = ["a"]
#
# Output: [["a"]]

# %%
from collections import Counter

strs = ["eat","tea","tan","ate","nat","bat"]

c = Counter(strs)
print(c)
# Out:
# Counter({'eat': 1, 'tea': 1, 'tan': 1, 'ate': 1, 'nat': 1, 'bat': 1})

# %%
for i in range(len(strs)):
    x[i] = Counter(strs[i])
    # print(x[0])  
    #   
    

# print(x[1])
# Out:
# Counter({'b': 1, 'a': 1, 't': 1, 0: Counter({'e': 1, 'a': 1, 't': 1}), 1: Counter({'t': 1, 'e': 1, 'a': 1}), 2: Counter({'t': 1, 'a': 1, 'n': 1}), 3: Counter({'a': 1, 't': 1, 'e': 1}), 4: Counter({'n': 1, 'a': 1, 't': 1}), 5: Counter({'b': 1, 'a': 1, 't': 1})})

# %%
strs = ["eat","tea","tan","ate","nat","bat"]

for i in range(len(strs)):
    x = Counter(strs[i])
    for j  in range(i+1,len(strs)):
        y = Counter(strs[j])

        if x == y:
            # print("x")
            print(strs[i],strs[j])
# Out:
# eat tea
# eat ate
# tea ate
# tan nat

# %%
strs = ["eat","tea","tan","ate","nat","bat"]

strs1 = []
for i in range(len(strs)):
    x1 = sorted(strs[i])
    z = "".join(x1)
    strs1.append(z)
    print(z)

print(strs1)
# Out:
# aet
# aet
# ant
# aet
# ant
# abt
# ['aet', 'aet', 'ant', 'aet', 'ant', 'abt']

# %%
strs = ["eat","tea","tan","ate","nat","bat"]

strs1 = []
for i in range(len(strs)):
    x1 = sorted(strs[i])
    z = "".join(x1)
    strs1.append(z)

# 🔥 grouping part
groups = {}

for i in range(len(strs1)):
    key = strs1[i]
    
    if key not in groups:
        groups[key] = []
    
    groups[key].append(strs[i])

print(list(groups.values()))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
groups = {}

for word in strs:
    key = "".join(sorted(word))
    
    if key not in groups:
        groups[key] = []
    
    groups[key].append(word)

print(list(groups.values()))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
