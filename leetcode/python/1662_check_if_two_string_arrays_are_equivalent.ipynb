# %% [markdown]
# Given two string arrays word1 and word2, return true if the two arrays represent the same string, and false otherwise.
#
# A string is represented by an array if the array elements concatenated in order forms the string.

# %%
word1 = ["ab", "c"]
word2 = ["a", "bc"]

c1 = ""
for i in range(len(word1)):
    c1 += word1[i]
print(c1)   

c2 = ""
for  j in range(len(word2)):
    c2 += word2[j]
print(c2)

if c1 == c2:
    print(True)
else:
    print(False)
# Out:
# abc
# abc
# True

# %%
word1 = ["ab", "c"]
word2 = ["a", "bc"]

c1 = "".join(word1)
print(c1)
c2 = "".join(word2)
print(c2)
print(c1==c2)
# Out:
# abc
# abc
# True

# %%
word1 = ["ab", "c"]
word2 = ["a", "bc"]

# %%
# Use Counter → when order doesn’t matter (like anagrams)
# Don’t use Counter → when order matters (like this problem)

# %%
# Counter(s1) == Counter(s2) 
# The order of characters does not matter, only their frequency
