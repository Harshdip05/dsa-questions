# %%
import bisect

# %%
nums = [1,3,5,6]
target = 2

bisect.insort(nums,target)
print(nums)

for i in range(len(nums)):
    if nums[i] == target:
        print(i) 
        break
else:
    print(-1)
# Out:
# [1, 2, 3, 5, 6]
# 1

# %%
#
